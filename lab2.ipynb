# %% [markdown]
# # This is my Lab 2

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://turner-ia340-2025-fall/Crime_Data_from_2020_to_Present.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.shape #show the number of rows and columns
# Out:
# (1004991, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06
# mean   2.202215e+08  1.339900e+03  1.069174e+01  1.115633e+03  1.400348e+00
# std    1.319718e+07  6.510613e+02  6.110255e+00  6.111605e+02  4.899691e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209159e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311103e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.004991e+06  1.004991e+06  1.004975e+06   327247.000000  1.004980e+06
# mean   5.001568e+02  2.891706e+01  3.056201e+02      363.955300  4.999174e+02
# ...

# %% [markdown]
# I have 1004991 rows and 28 columns. About half are numeric and the other half are nonnumeric. It has very precise geolocation data.

# %%
#rename columns
df = df.rename(columns={"Crm Cd Desc": "Crime Description"})
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                    Crime Description  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# DR_NO                      0
# Date Rptd                  0
# DATE OCC                   0
# TIME OCC                   0
# AREA                       0
# AREA NAME                  0
# Rpt Dist No                0
# Part 1-2                   0
# Crm Cd                     0
# Crime Description          0
# Mocodes               151619
# Vict Age                   0
# Vict Sex              144644
# Vict Descent          144656
# Premis Cd                 16
# Premis Desc              588
# Weapon Used Cd        677744
# Weapon Desc           677744
# Status                     1
# Status Desc                0
# Crm Cd 1                  11
# Crm Cd 2              935831
# Crm Cd 3             1002677
# Crm Cd 4             1004927
# LOCATION                   0
# Cross Street          850755
# LAT                        0
# LON                        0
# dtype: int64

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# DR_NO                0
# Date Rptd            0
# DATE OCC             0
# TIME OCC             0
# AREA                 0
# AREA NAME            0
# Rpt Dist No          0
# Part 1-2             0
# Crm Cd               0
# Crime Description    0
# Mocodes              0
# Vict Age             0
# Vict Sex             0
# Vict Descent         0
# Premis Cd            0
# Premis Desc          0
# Weapon Used Cd       0
# Weapon Desc          0
# Status               0
# Status Desc          0
# Crm Cd 1             0
# Crm Cd 2             0
# Crm Cd 3             0
# Crm Cd 4             0
# LOCATION             0
# Cross Street         0
# LAT                  0
# LON                  0
# dtype: int64

# %% [markdown]
# I replaced the header "Crm Cd Desc" with "Crime Description". There was hundreds of thousands of missing values, so I removed them.

# %%
df['Crime Description']
# Out:
# 27751                                       BRANDISH WEAPON
# 134755                                      BRANDISH WEAPON
# 363765                                       RAPE, FORCIBLE
# 372524                                              ROBBERY
# 490101    SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...
# 537834                                      RAPE, ATTEMPTED
# 586003                                           KIDNAPPING
# 728576                                              ROBBERY
# 809419                                              ROBBERY
# 934749                                      ORAL COPULATION
# Name: Crime Description, dtype: object

# %%
df.sort_values(by='Crime Description') #sort data by a column
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 586003  221401314  11/10/2022 12:00:00 AM  11/10/2022 12:00:00 AM      2117
# 934749  241905348  02/04/2024 12:00:00 AM  02/03/2024 12:00:00 AM      1100
# 537834  221718232  12/25/2022 12:00:00 AM  12/25/2022 12:00:00 AM      1150
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 372524  210209196  05/08/2021 12:00:00 AM  05/08/2021 12:00:00 AM       230
# 728576  231717599  11/15/2023 12:00:00 AM  11/15/2023 12:00:00 AM       400
# 809419  231915572  10/21/2023 12:00:00 AM  10/21/2023 12:00:00 AM         1
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 27751     19     Mission         1924         1     761
# ...

# %%
df[0:5] #slice by rows
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 372524  210209196  05/08/2021 12:00:00 AM  05/08/2021 12:00:00 AM       230
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
#
#         AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 27751     19    Mission         1924         1     761
# 134755     6  Hollywood          657         1     761
# 363765     6  Hollywood          659         1     121
# 372524     2    Rampart          279         1     210
# 490101     6  Hollywood          646         1     821
#
#                                         Crime Description  ... Status  \
# 27751                                     BRANDISH WEAPON  ...     AA
# ...

# %%
df = df[(df['Crm Cd 1']>=0) & (df['Crm Cd 2']>=0) & (df['Crm Cd 3']>=0)] #filter data
df.describe()
# Out:
#               DR_NO     TIME OCC       AREA  Rpt Dist No   Part 1-2  \
# count  1.000000e+01    10.000000  10.000000    10.000000  10.000000
# mean   2.192602e+08  1341.300000  12.500000  1303.700000   1.100000
# std    1.352419e+07   882.411979   6.720615   664.544631   0.316228
# min    2.006134e+08     1.000000   2.000000   279.000000   1.000000
# 25%    2.103112e+08   575.000000   6.000000   657.500000   1.000000
# 50%    2.210010e+08  1550.000000  15.500000  1595.000000   1.000000
# 75%    2.292178e+08  2095.250000  18.500000  1875.750000   1.000000
# max    2.419053e+08  2300.000000  19.000000  1983.000000   2.000000
#
#            Crm Cd   Vict Age   Premis Cd  Weapon Used Cd    Crm Cd 1  \
# count   10.000000  10.000000   10.000000       10.000000   10.000000
# mean   494.600000  33.500000  228.100000      244.600000  419.800000
# std    341.291078  19.682197  256.205842      140.814456  307.157506
# min    121.000000   0.000000  101.000000      102.000000  121.000000
# ...

# %% [markdown]
# I selected sorted and filtered by the different types of crimes. There are many more specifications of types of crimes than I previously thought.

# %%
sum_time_by_crime = df.groupby('TIME OCC')['Crm Cd'].mean() # calculate the type of crime by time occured
sum_time_by_crime.head()
# Out:
# TIME OCC
# 1       210.0
# 230     210.0
# 400     210.0
# 1100    820.0
# 1150    122.0
# Name: Crm Cd, dtype: float64

# %%
ax = sum_time_by_crime.nlargest(10).plot.bar() # use a bar chart to show the results of the crimes
ax.set_xlabel("Time Occured")
ax.set_ylabel("Type of Crime")
ax.set_title("Crime Type by Time ")
# Out:
# <Axes: xlabel='TIME OCC'>

# %% [markdown]
# This data shows time by crime type. The crimes that occured during the day were 210 (robbery). The crimes that occured late at night were mostly sexual crimes, indicated by their code numbers.

# %%
sum_location_by_time = df.groupby('AREA')['TIME OCC'].mean() # calculate the crime occured by area
sum_location_by_time.head()
# Out:
# AREA
# 2      230.000000
# 6     2093.333333
# 14    2117.000000
# 17     775.000000
# 19    1078.666667
# Name: TIME OCC, dtype: float64

# %%
ax = sum_location_by_time.nlargest(10).plot.bar() # use a bar chart to show the results of the areas and time of crimes committed
ax.set_xlabel("Area")
ax.set_ylabel("Time Committed")
ax.set_title("Area by Time Crime Committed")
# Out:
# Text(0.5, 1.0, 'Area by Time Crime Committed')

# %% [markdown]
# This graph shows the average time that the crime was committed for each area code. Hollywood (6), for example shows that most crimes occure after 8:00 PM (2000 military time). Rampart (2), on the other hand shows most crimes occur midday. I don't know where this place is, but I could assume it is a poor location, because most robberies occur midday and robberies would occur in locations where people need money.
